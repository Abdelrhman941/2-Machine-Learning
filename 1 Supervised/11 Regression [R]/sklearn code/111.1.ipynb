# %%
from sklearn.linear_model import LinearRegression                                               # type: ignore
from sklearn.model_selection import train_test_split                                            # type: ignore
from sklearn.metrics import mean_absolute_error , mean_squared_error , median_absolute_error    # type: ignore
#----------------------------------------------------
# LR_model = LinearRegression(fit_intercept=True,copy_X=True,n_jobs=-1)
# LR_model.fit(X_train, y_train)

## Calculating Details:
# print(f'Linear Regression Train Score : {LR_model.score(X_train, y_train)}')
# print(f'Linear Regression Test  Score : {LR_model.score(X_test, y_test)}')
# print(f'Linear Regression Coef : \n{LR_model.coef_}')
# print(f'Linear Regression intercept : {LR_model.intercept_}')
# print('----------------------------------------------------')

## Calculating Prediction:
# y_pred = LR_model.predict(X_test)
# print(f'Predicted Value for Linear Regression : \n{ y_pred[:10]}\n')
# print(f'Actual    Value for Linear Regression : \n{ y_test[:10]}\n')

########################################################
## Calculating Mean Absolute Error:
# MAEValue = mean_absolute_error(y_test, y_pred, multioutput='uniform_average')   # it can be raw_values
# print(f'Mean  Absolute Error Value : {MAEValue}')
# ##########################################################
# #Calculating Mean Squared Error
# MSEValue = mean_squared_error(y_test, y_pred, multioutput='uniform_average')    # it can be raw_values
# print(f'Mean   Squared Error Value : {MSEValue}')
# ##########################################################
# #Calculating Median Squared Error
# MdSEValue = median_absolute_error(y_test, y_pred)
# print(f'Median Squared Error Value : {MdSEValue}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.datasets import load_breast_cancer     # type: ignore

breast_cancerData = load_breast_cancer()

X = breast_cancerData.data
y = breast_cancerData.target

print(X.ndim)   
print(y.ndim)
# Out:
# 2
# 1

# %%
# Splitting data:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44, shuffle =True)
print(f"X_train shape: {X_train.shape}")
print(f"X_test  shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test  shape: {y_test.shape}")
# Out:
# X_train shape: (381, 30)
# X_test  shape: (188, 30)
# y_train shape: (381,)
# y_test  shape: (188,)

# %%
# Applying Linear Regression Model:
LinearRegressionModel = LinearRegression()
LinearRegressionModel.fit(X_train, y_train)

# Calculating Details:
print(f'Linear Regression Train Score : {LinearRegressionModel.score(X_train, y_train)}')
print(f'Linear Regression Test  Score : {LinearRegressionModel.score(X_test, y_test)}\n')

print(f'Linear Regression Coef : \n{LinearRegressionModel.coef_}\n')
print(f'Linear Regression intercept : {LinearRegressionModel.intercept_}')
# Out:
# Linear Regression Train Score : 0.7813005644449855
# Linear Regression Test  Score : 0.7039149493406971
#
# Linear Regression Coef :
# [ 2.17087377e-01  2.22427430e-03 -4.26547807e-03 -1.42165044e-03
#   1.57589379e+00  2.57465686e+00 -1.83264725e+00 -8.00903103e-01
#  -1.44120482e+00  7.77112282e+00 -5.78926951e-01 -4.82761101e-03
#   1.12382129e-01 -1.56565891e-03 -9.06326616e+00  2.15996709e+00
#   1.90821618e+00 -6.38951155e+00 -8.40465440e+00  7.01431192e+00
#  -2.26549029e-01 -1.20860294e-02 -7.01510176e-03  1.73403196e-03
#  -8.86115091e-01 -3.01932008e-03 -2.08644786e-01 -1.49006431e+00
#   4.05687337e-01 -5.70029089e+00]
#
# Linear Regression intercept : 2.4641823010597

# %%
# Calculating Prediction:
y_pred = LinearRegressionModel.predict(X_test)
print(f'Predicted Value for Linear Regression : \n{ y_pred[:10]}\n')
print(f'Actual    Value for Linear Regression : \n{ y_test[:10]}\n')
# Out:
# Predicted Value for Linear Regression :
# [ 0.29096595 -0.07611523  0.77994351 -0.39119752  0.5497603   0.78333362
#   1.00178242  0.70201387  0.0416031   1.17501409]
#
# Actual    Value for Linear Regression :
# [0 0 1 0 1 1 1 1 0 1]

# %%
# Calculating Mean Absolute Error:
MAEValue = mean_absolute_error(y_test, y_pred, multioutput='uniform_average')   # it can be raw_values
print(f'Mean   Absolute Error Value  : {MAEValue}')
##########################################################
#Calculating Mean Squared Error
MSEValue = mean_squared_error(y_test, y_pred, multioutput='uniform_average')    # it can be raw_values
print(f'Mean   Squared  Error Value  : {MSEValue}')
##########################################################
#Calculating Median Squared Error
MdSEValue = median_absolute_error(y_test, y_pred)
print(f'Median Squared  Error Value  : {MdSEValue}')
# Out:
# Mean   Absolute Error Value  : 0.20516658159444925
# Mean   Squared  Error Value  : 0.06835825071808264
# Median Squared  Error Value  : 0.17348715882991994
