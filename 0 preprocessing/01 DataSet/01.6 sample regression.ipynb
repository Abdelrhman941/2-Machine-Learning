# %%
from sklearn.datasets import make_regression
'''
X ,y = make_regression(n_samples=100, n_features=100, n_informative=10, n_targets=1, bias=0.0, effective_rank=None,
                    tail_strength=0.5, noise=0.0, shuffle=True, coef=False, random_state=None)
'''

X ,y = make_regression(n_samples=10000, n_features=500,shuffle=True)

# %%
# X Data
print(f'X Data  : \n {X[:1]} \n')
print(f'X shape : {X.shape} ')
# Out:
# X Data :
#  [[-0.94136277 -0.05423326  0.67770676  0.74886998 -0.53083017 -0.41922401
#   -0.47951847 -0.27397511 -1.35644011 -0.97250081  0.03157201  0.4950469
#    1.1963359   1.57482856 -1.43455654  0.88844972  1.43691852  0.5400468
#   -0.29311269  1.7248851  -1.5404543  -1.21538883 -0.54091765  0.49482852
#   -0.45313134 -0.40053685 -0.1292011  -0.18147674  2.29950458  1.56877299
#   -0.11590789  2.01850307  0.79949654  0.57037621  0.6498381  -0.42131753
#   -1.23620973 -0.73978115 -1.37096913  0.05928753 -0.98607253 -0.58878924
#   -0.51663959 -1.17194234  0.57055763  0.27512988 -2.14839425  0.77399478
#    0.90339036 -0.72174707 -1.59204091  0.4974752  -1.93788631 -0.21149511
#   -0.43988845  2.16826718  0.10975005  1.22144892  0.51988989 -1.88833447
#   -1.12194104  1.40993141  0.30008244 -0.98831802  1.62210425 -0.56663722
#    0.26278544  0.9755077  -0.92658894  0.56260982 -0.62631414 -1.32579319
#   -0.18688986  0.93087796  0.7773208   0.26474993  0.49931439  1.39047966
# ...

# %%
# y Data
print(f'y Data  : \n {y[:100]} \n')
print(f'y shape : {y.shape} ')
# Out:
# y Data  :
#  [ 160.39797244  122.25901373  -28.5362846    44.05630731 -101.81980683
#    53.98916333   27.70292143  -27.18415571  156.59024303  -33.36729945
#  -117.46221432  356.0207655   117.74787203   72.06824763   25.56810391
#  -228.92012391  267.19935224 -272.9451528    25.8003314  -310.95124034
#    68.84525957  191.20869157   13.05782009  -86.16305223  291.49369596
#    30.98297155 -349.92541844  -67.30569009  -38.72396138  186.30739667
#  -201.79747872 -222.65659158  -61.43750139   98.41635983  -15.697324
#  -217.53974614  -59.00941029  -82.73489643  -85.59202567  -34.87828165
#   371.80488922    2.70290452 -133.1972329   172.60198759  299.58184432
#   -41.09534639  -13.85798799 -303.3681806    95.14224439 -163.94299575
#  -107.7477874  -162.85475944 -525.57832801 -230.572949   -169.00110079
#    71.36043194   10.79621548  -46.02352285  -60.05452973   65.90603207
#  -178.50443275   -3.04430248 -318.42396767  -97.43272266   40.67725032
# ...
